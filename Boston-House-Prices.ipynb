# %% [markdown]
# # The Boston House Prices Dataset
# ![Boston skyline](Boston.jpg)

# %% [markdown]
# <a id="top-page"></a>

# %% [markdown]
# ***

# %% [markdown]
# ## Submitted by: Valerie Walsh G00364748
# ## Submission Date: 29th Nov 2019

# %% [markdown]
# ***

# %% [markdown]
# ### Module: Machine Learning
# ### Course: Computer Science in Data Analytics
# ### Institute: Galway-Mayo I.T.

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Table of Contents
# ### Introduction
# ### Statement of Work
# ### Technology Used
# ### Aim of Investigation
# ### Background
# ### Findings
# ### References

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Introduction

# %% [markdown]
# This repository has been created as apart of my ongoing studies within Higher Diploma Computer Science in Data Analytics at GMIT. <br>
# It is my intention to use this repository to investigate the Boston House Prices Dataset using the available functions within Jupyter.

# %% [markdown]
# ***

# %% [markdown]
# ## Statement of Work

# %% [markdown]
# This is a statement to confirm that the work submitted within this repository is my own work. <br>
# Any information obtained via 3rd party as apart of my research has been referenced appropriately. <br>
# I can therefore confirm that my submitted work is in line with the Quality Assurance Framework of GMIT.

# %% [markdown]
# ***

# %% [markdown]
# ## Technology Used

# %% [markdown]
# - Anaconda software package
# - Python Programming Language
# - Command Prompt
# - Jupyter Notebook
# - GitHub.com
# - LearnOnline (GMIT)

# %% [markdown]
# ***

# %% [markdown]
# ## Aim of the Investigation

# %% [markdown]
# - To uses descriptive statistics and plots to describe and display the Boston House Prices dataset
# - To analyse whether there is a signiﬁcant diﬀerence in median house prices between houses that are along the Charles river and those that aren’t. If there is I shall use this notebook to explain and discuss my findings.
# - And finally using the Keras package, I am aiming to create a neural network that can predict the median house price based on the other variables in the dataset

# %% [markdown]
# ***

# %% [markdown]
# ## Background

# %% [markdown]
# ##### What is 'The Boston House Prices Dataset'?
# The Boston House dataset is made up of information *"collected by the U.S. Census Service concerning housing in the area of Boston Mass."* [8] <br>
#
# The dataset is made up of 506 cases and 14 attributes. Each case refers to a Boston suburb or town.
# <br><br>
#
# ![Variables](variables.PNG)
#
# <br>
#
# The dataset was published by Harrison and Rubinfeld in 1978. <br>
# The reason for the dataset was to investigate the willingness of homeowners to pay for clean air when it came to purchasing a property within the suburbs of Boston. <br>
# Along with the expected variables of a housing dataset eg crime rate, rooms per house, owned occupied; this dataset contains a variable relating to 'nitric oxide concentration'. This variable forms a big element within the existence of the dataset.
#
# <br>

# %% [markdown]
# ***

# %% [markdown]
# ### Describing the Boston house prices dataset

# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd
from sklearn.cross_validation import ShuffleSplit

# Pretty display for notebooks
# %matplotlib inline

# Load the Boston housing dataset
data = pd.read_csv('housing.csv')
prices = data['MEDV']
features = data.drop('MEDV', axis = 1)

# Success
print ("Boston housing dataset has {0} data points with {1} variables each".format(*data.shape))
# Out:
# C:\Users\valer\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-35-5c4dcd488ad3> in <module>()
#       8
#       9 # Load the Boston housing dataset
# ---> 10 data = pd.read_csv('housing.csv')
#      11 prices = data['MEDV']
#      12 features = data.drop('MEDV', axis = 1)
#
# ...

# %%
# Read data
import pandas as pd
import numpy as np

bos=pd.read_csv('Boston.csv',header=[0,1],index_col=[0])
bos
# Out:
# crim        zn  indus chas    nox    rm    age  dis rad  tax ptratio   black  \
# 0.00632     18   2.31    0  0.538     7   65.2 4.09   1  296    15.3   396.9
# 0.02731    0.0   7.07    0  0.469  6.00   78.9  5.0   2  242    17.8  396.90
# 0.02729    0.0   7.07    0  0.469  7.00   61.1  5.0   2  242    17.8  392.83
# 0.03237    0.0   2.18    0  0.458  7.00   45.8  6.0   3  222    18.7  394.63
# 0.06905    0.0   2.18    0  0.458  7.00   54.2  6.0   3  222    18.7  396.90
# 0.02985    0.0   2.18    0  0.458  6.43   58.7  6.0   3  222    18.7  394.12
# 0.08829   12.5   7.87    0  0.524  6.00   66.6  6.0   5  311    15.2  395.60
# 0.14455   12.5   7.87    0  0.524  6.00   96.1  6.0   5  311    15.2  396.90
# 0.21124   12.5   7.87    0  0.524  6.00  100.0  6.0   5  311    15.2  386.63
# 0.17004   12.5   7.87    0  0.524  6.00   85.9  7.0   5  311    15.2  386.71
# 0.22489   12.5   7.87    0  0.524  6.00   94.3  6.0   5  311    15.2  392.52
# ...

# %%
bos.describe()
# Out:
# crim             zn       indus        chas         nox          rm  \
# 0.00632          18        2.31           0       0.538           7
# count    505.000000  505.000000  505.000000  505.000000  505.000000
# mean      11.350495   11.154257    0.069307    0.554728    6.261683
# std       23.343704    6.855868    0.254227    0.115990    0.721232
# min        0.000000    0.460000    0.000000    0.385000    4.000000
# 25%        0.000000    5.190000    0.000000    0.449000    6.000000
# 50%        0.000000    9.690000    0.000000    0.538000    6.000000
# 75%       12.500000   18.100000    0.000000    0.624000    7.000000
# max      100.000000   27.740000    1.000000    0.871000    9.000000
#
# crim            age         dis         rad         tax     ptratio  \
# 0.00632        65.2        4.09           1         296        15.3
# count    505.000000  505.000000  505.000000  505.000000  505.000000
# mean      68.581584    3.774178    9.566337  408.459406   18.461782
# ...

# %%
prices = data['MEDV']
# TODO: Minimum price of the data
minimum_price = np.min(prices)
# Alternative using pandas
# minimum_price = prices.min()

# TODO: Maximum price of the data
maximum_price = np.max(prices)
# Alternative using pandas
# maximum_price = prices.max()

# TODO: Mean price of the data
mean_price = np.mean(prices)
# Alternative using pandas
# mean_price = prices.mean()

# TODO: Median price of the data
median_price = np.median(prices)
# Alternative using pandas
# median_price = prices.median()

# TODO: Standard deviation of prices of the data
std_price = np.std(prices)
# Alternative using pandas 
# std_price = prices.std(ddof=0)

# There are other statistics you can calculate too like quartiles
first_quartile = np.percentile(prices, 25)
third_quartile = np.percentile(prices, 75)
inter_quartile = third_quartile - first_quartile

# Show the calculated statistics
print ("Statistics for Boston housing dataset:\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-1de5dca61404> in <module>()
# ----> 1 prices = data['MEDV']
#       2 # TODO: Minimum price of the data
#       3 minimum_price = np.min(prices)
#       4 # Alternative using pandas
#       5 # minimum_price = prices.min()
#
# NameError: name 'data' is not defined

# %%
# I attempted to recreate another method of describe() but could not get the syntax right
# I have chosen to leave the code in via comments for visibility
# <!--- boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names) -->
# <!-- boston.head() -->

# https://alvinalexander.com/technology/markdown-comments-syntax-not-in-generated-output
# https://gist.github.com/jonikarppinen/47dc8c1d7ab7e911f4c9

# %%
import matplotlib.pyplot as plt

plt.subplot(1,5,1)
l = bos.min()
plt.hist(l)
plt.title("Min")
plt.xlabel("x axis")
plt.ylabel("y axis")

plt.subplot(1,5,2)
y = bos.max()
plt.hist(y)
plt.title("Max")
plt.xlabel("x axis")
plt.ylabel("y axis")

plt.subplot(1,5,3)
z = bos.mean()
plt.hist(z)
plt.title("Mean")
plt.xlabel("x axis")
plt.ylabel("y axis")
# Out:
# Text(0,0.5,'y axis')

# %% [markdown]
# An interesting article involving the Boston house prices dataset used scikit-learn to investigate the data  https://medium.com/@haydar_ai/learning-data-science-day-9-linear-regression-on-boston-housing-dataset-cd62a80775ef

# %%
from sklearn.datasets import load_boston
boston = load_boston()

print(boston.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR'])

# %% [markdown]
# ***

# %% [markdown]
# ## Findings

# %% [markdown]
# Upon researching for this assignment, it became clear the dataset is used by many in order to learn and research within the area of  Regression Algorithm.

# %% [markdown]
# ##### __Summary__

# %% [markdown]
# In summary to the above ....
# <br><br>
# Having researched for this assignment, I have gained a knowledge of new Python packages.
# I learned new ways to format and design my Jupyter notebook via the form of Markdown.

# %% [markdown]
# ***

# %% [markdown]
# ## References

# %% [markdown]
# 1. Anaconda  https://www.anaconda.com/
# 2. Python Programming Language https://www.python.org/
# 3. Github.com www.github.com
# 4. Jupyter Notebook https://jupyter.org/
# 5. https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html
# 6. https://jupyter-notebook.readthedocs.io/en/stable/index.html
# 7. https://gist.github.com/asabaylus/3071099
# 8. https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html
# 9. https://www.sciencedirect.com/science/article/abs/pii/0095069678900062?via%3Dihub
# 10. https://bookdown.org/egarpor/PM-UC3M/lm-ii-lab-boston.html
# 11. https://alvinalexander.com/technology/markdown-comments-syntax-not-in-generated-output
# 12. <br>
# 13. <br>
# 14. <br>
# 15. <br>
# 16. <br>
# 17. <br>
# 18. <br>
# 19. <br>
# 20. <br>
# 21. <br>
# 22. <br>

# %% [markdown]
# ***
# ***

# %% [markdown]
# <a href='#top-page' id='top-page' class='anchor' aria-hidden='true'>Back to top</a>
